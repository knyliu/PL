# %%
# 2023 與 2022 QS排名 比較
import pandas as pd

# 使用 pandas 的 read_csv 函式讀取 CSV 檔案並將其轉換為 DataFrame
df_2023 = pd.read_csv('2023_r.csv')
df_2022 = pd.read_csv('2022_r.csv')


print(df_2023)
print(df_2022)
# Out:
#       Rank                                       Institution LocationCode  \
# 0        1      Massachusetts Institute of Technology (MIT)            US
# 1        2                           University of Cambridge           UK
# 2        3                               Stanford University           US
# 3        4                              University of Oxford           UK
# 4        5                                Harvard University           US
# ...    ...                                               ...          ...
# 1417  1418  Universidad Nacional Autónoma de Honduras (UNAH)           HN
# 1418  1419                Universidad Tecnológica de Bolívar           CO
# 1419  1420                    Université Mohammed V de Rabat           MA
# 1420  1421                             University of Craiova           RO
# 1421  1422                              University of Oradea           RO
#
#             Location  ArScore ArRank  ErScore ErRank  FsrScore FsrRank  ...  \
# 0      United States    100.0      5    100.0      4     100.0      14  ...
# 1     United Kingdom    100.0      2    100.0      2     100.0      11  ...
# 2      United States    100.0      4    100.0      5     100.0       6  ...
# 3     United Kingdom    100.0      3    100.0      3     100.0       8  ...
# 4      United States    100.0      1    100.0      1      99.4      35  ...
# ...              ...      ...    ...      ...    ...       ...     ...  ...
# 1417        Honduras      4.6   501+      5.8   501+       3.6    601+  ...
# 1418        Colombia      3.0   501+      5.8   501+       2.4    601+  ...
# 1419         Morocco      2.8   501+      2.6   501+       3.2    601+  ...
# 1420         Romania      3.3   501+      1.8   501+       2.7    601+  ...
# 1421         Romania      4.0   501+      2.1   501+       3.3    601+  ...
#
#       CpfRank IfrScore  IfrRank IsrScore  IsrRank IrnScore  IrnRank GerScore  \
# 0           5    100.0       54     90.0      109     96.1       58    100.0
# 1          55    100.0       60     96.3       70     99.5        6    100.0
# 2           9     99.8       74     60.3      235     96.3       55    100.0
# 3          64     98.8      101     98.4       54     99.9        3    100.0
# 4           2     76.9      228     66.9      212    100.0        1    100.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1417     601+      1.7     601+      NaN      NaN      8.1     601+      NaN
# 1418     601+      9.3     601+      1.3     601+      8.8     601+     30.9
# 1419     601+      5.2     601+      2.8     601+     51.1     601+      NaN
# 1420     601+      NaN      NaN      NaN      NaN      7.5     601+      8.7
# 1421     601+      1.7     601+      7.9     601+     16.6     601+      9.7
#
#       GerRank ScoreScaled
# 0           3         100
# 1           9        98.8
# 2           2        98.5
# 3           7        98.4
# 4           1        97.6
# ...       ...         ...
# 1417      NaN           -
# 1418      403           -
# 1419      NaN           -
# 1420     601+           -
# 1421     601+           -
#
# [1422 rows x 21 columns]
#       year rank_display                                    university  score  \
# 0     2022            1  Massachusetts Institute of Technology (MIT)   100.0
# 1     2022            2                          University of Oxford   99.5
# 2     2022           =3                           Stanford University   98.7
# 3     2022           =3                       University of Cambridge   98.7
# 4     2022            5                            Harvard University   98.0
# ...    ...          ...                                           ...    ...
# 1295  2022        1201+                           Université de Tunis    NaN
# 1296  2022        1201+                  Université de Tunis El Manar    NaN
# 1297  2022        1201+                            Yarmouk University    NaN
# 1298  2022        1201+                   Yildiz Technical University    NaN
# 1299  2022        1201+                            Zagazig University    NaN
#
#                                                    link         country  \
# 0     https://www.topuniversities.com/universities/m...   United States
# 1     https://www.topuniversities.com/universities/u...  United Kingdom
# 2     https://www.topuniversities.com/universities/s...   United States
# 3     https://www.topuniversities.com/universities/u...  United Kingdom
# 4     https://www.topuniversities.com/universities/h...   United States
# ...                                                 ...             ...
# 1295  https://www.topuniversities.com/universities/u...         Tunisia
# 1296  https://www.topuniversities.com/universities/u...         Tunisia
# 1297  https://www.topuniversities.com/universities/y...          Jordan
# 1298  https://www.topuniversities.com/universities/y...          Turkey
# 1299  https://www.topuniversities.com/universities/z...           Egypt
#
#            city         region  \
# 0     Cambridge  North America
# 1        Oxford         Europe
# 2      Stanford  North America
# 3     Cambridge         Europe
# 4     Cambridge  North America
# ...         ...            ...
# 1295      Tunis         Africa
# 1296      Tunis         Africa
# 1297      Irbid           Asia
# 1298   Istanbul           Asia
# 1299    Zagazig         Africa
#
#                                                    logo
# 0     https://www.topuniversities.com/sites/default/...
# 1     https://www.topuniversities.com/sites/default/...
# 2     https://www.topuniversities.com/sites/default/...
# 3     https://www.topuniversities.com/sites/default/...
# 4     https://www.topuniversities.com/sites/default/...
# ...                                                 ...
# 1295  https://www.topuniversities.com/sites/default/...
# 1296  https://www.topuniversities.com/sites/default/...
# 1297  https://www.topuniversities.com/sites/default/...
# 1298  https://www.topuniversities.com/sites/default/...
# 1299  https://www.topuniversities.com/sites/default/...
#
# [1300 rows x 9 columns]

# %%
# 從 DataFrame 中取出學生名稱欄位，假設欄位名稱為 '學生名稱'，你可以根據實際情況調整
uni_names_2023 = df_2023['Institution']
uni_names_2022 = df_2022['university']


# 將學生名稱轉換為 set 資料型態
uni_names_2023_set = set(uni_names_2023)
uni_names_2022_set = set(uni_names_2022)

#print(uni_names_2023_set)
print(len(uni_names_2023_set))

#print(uni_names_2022_set)
print(len(uni_names_2022_set))
# Out:
# 1422
# 1300

# %%
#2023、2022皆在QS名單內的學校
print(uni_names_2023_set & uni_names_2022_set)
# Out:
# {'University of Hradec Kralove', 'University of California, Berkeley (UCB)', 'Birla Institute of Technology and Science, Pilani', 'Lomonosov Moscow State University', 'Aligarh Muslim University', 'Inha University', 'National Sun Yat-sen University', 'Charles Sturt University ', 'Universidad Pontificia Bolivariana ', 'Universidade Federal do Ceará (UFC)', 'Rochester Institute of Technology (RIT)', 'Syracuse University', 'Kingston University, London', 'University of Waikato', 'Université de Toulouse II-Le Mirail', 'California Institute of Technology (Caltech)', 'HSE University', 'Universidad del Bío-Bío', 'Sultan Qaboos University', 'Universität Stuttgart', 'Universidad Tecnológica de la Habana José Antonio Echeverría, Cujae', 'Technische Universität Wien', 'Universidad Central de Venezuela', 'Al-Azhar University', 'Princess Nourah bint Abdulrahman University', 'Pukyong National University ', 'University of Tromsø The Arctic University of Norway', 'University of Leicester', 'University of Delaware', 'University of Aveiro', 'Universiti Malaysia Sabah (UMS)', 'University of Science and Technology of China', 'Christian-Albrechts-University zu Kiel', 'Southwest University', 'Rutgers University–Newark', 'University of Wisconsin Milwaukee ', 'Humboldt-Universität zu Berlin', 'Ain Shams University ', 'Birmingham City University ', 'The University of Western Australia', 'University of Maribor', 'University of Debrecen', 'Université de Tunis', 'Free University of Bozen-Bolzano', 'Universitat Ramon Llull', 'Hallym University ', 'Coventry University', 'University of California, Riverside', 'Michigan Technological University', 'Tokai University', 'Universitat Autònoma de Barcelona', 'Ivan Franko National University of Lviv', 'University of Huddersfield', 'University of Michigan-Ann Arbor', 'Sofia University "St. Kliment Ohridski"', 'Saint Petersburg State University', 'Tecnológico de Costa Rica -TEC', 'Technical University of Kosice', 'Escuela Politécnica Nacional', 'Université de Lorraine', 'Shanghai International Studies University', 'National Central University', 'Nankai University', 'Southern Methodist University', 'Deakin University', 'Rice University', 'Universidad de La Serena', 'An-Najah National University', 'Norwegian University of Science And Technology', 'Carleton University', 'International Islamic University Malaysia (IIUM)', 'Loyola University Chicago', 'Universidad de Antioquia', 'Bielefeld University', 'Amity University', 'Northwestern University', 'University of Naples - Federico II', 'University of Bialystok', 'Essex, University of', 'Harvard University', 'University of Alicante', 'University of International Business and Economics', 'National Taiwan Ocean University', 'Ohio University', 'Kazakh Ablai Khan University of International Relations and World Languages', 'Middle East Technical University', 'China Agricultural University ', 'Arizona State University', 'University of Belgrade', 'Católica de Córdoba', 'Universidad Industrial de Santander - UIS', 'University of Kent', 'Ural Federal University - UrFU', 'Tel Aviv University', 'Al Quds University The Arab University in Jerusalem', ' University of Dundee', 'University of the Philippines', 'Sorbonne University', 'Charles University', 'Pontifícia Universidade Católica de São Paulo', 'Baku State University', 'University of Miami', 'Indiana State University', 'University of Tulsa', 'Vellore Institute of Technology (VIT)', 'Universidad Católica de Santiago de Guayaquil', 'Universidad Nacional Agraria la Molina', 'Pakistan Institute of Engineering and Applied Sciences (PIEAS)', 'Université Laval', 'Jamia Millia Islamia', 'University of Groningen', 'University of Montana Missoula ', 'University of Ghana', 'Università degli studi di Bergamo', 'University of Missouri, Columbia', 'Kyushu University', 'Universidad del Salvador', 'Tomas Bata University in Zlin', 'Anadolu University', 'Belarusian State University', 'Universidade Federal da Bahia', 'University of Bradford', 'Izmir I ...

# %%
#2023、2022皆在QS名單內的學校 數量
print(len(uni_names_2023_set & uni_names_2022_set))
# Out:
# 1275

# %%
#2022在，但2023不在 QS名單內的學校 及 數量
print(len(uni_names_2022_set - uni_names_2023_set))
print(uni_names_2022_set - uni_names_2023_set)
# Out:
# 25
# {"Université Côte d'Azur", 'Sciences Po', 'Universidad Nacional de Tucumà¡n', 'S. Toraighyrov Pavlodar State University', 'Ryerson University', "King Mongkut's Institute of Technology Ladkrabang", 'Universidad de Panamá - UP', 'MGIMO School of Business and International Proficiency', 'Universidad Nacional Costa Rica', 'Bogaziçi Üniversitesi', 'Sungkyunkwan University (SKKU)', 'Université de Paris', 'Universitatea de Vest din Timisoara /  West University of Timisoara', 'Smith College', 'Universidad Nacional Autónoma de México  (UNAM)', 'Khalifa University', 'Indian Institute of Information Technology, Allahabad', 'National Technical University  "Kharkiv Polytechnic Institute"', 'Pontificia Universidad Catolica del Peru', 'Ulm University', 'Universität  Leipzig', 'Università Cattolica del Sacro Cuore', 'Università di Padova', 'Vilnius Gediminas Technical University (VILNIUS TECH)', 'Universidad Autonoma Chapingo'}

# %%
#2023在，但2022不在 QS名單內的學校 及 數量
print(len(uni_names_2023_set - uni_names_2022_set))
print(uni_names_2023_set - uni_names_2022_set)
# Out:
# 147
# {'China University of Petroleum', 'Chandigarh University', 'University of Madras', 'Kwansei Gakuin University', 'Zhengzhou University', 'Universidad de Carabobo', 'Western Washington University', 'University of Missouri Saint Louis', 'Wesleyan University', 'CUNY The City College of New York', 'Óbuda University', 'Università\xa0di Padova', 'Universidad de Las Américas (UDLA) Ecuador', 'Khalifa University of Science and Technology', 'University of Alabama, Birmingham', 'Vancouver Island University', 'Universidad del Valle de Mexico (UVM)', 'University of Northern British Columbia', 'University of Louisville', 'Soongsil University', 'Universitatea de Vest din Timisoara / West University of Timisoara', 'Gebze Yüksek Teknoloji Enstitüsü (GYTE)', 'MGIMO University', 'Ocean University of China', 'Hohai University', 'University of Hawaii at Hilo', 'Universidad de Piura', 'University Ulm', 'Kharkiv National University of Radio Electronics ', 'University of Warmia and Mazury in Olsztyn', 'Illinois State University', 'Nanjing Normal University', 'Universidad del Zulia', 'Universidad Católica de La Santísima Concepción - UCSC', 'Shanghai Normal University', 'University of Pannonia', 'Universidad Mayor de San Simón Cochabamba', 'National Technical University "Kharkiv Polytechnic Institute"', 'Université Paris Cité', 'Northwest Agriculture and Forestry University', 'University of Alaska Fairbanks', 'University of Central Oklahoma', 'Sungkyunkwan University(SKKU)', 'Kyrgyz-Turkish Manas University', 'Alfaisal University', 'California State University Long Beach', 'Central Michigan University', 'Universidad La Salle (ULSA)', 'Universidad de Oriente Santiago de Cuba', 'Fundación Universidad De Bogotá-Jorge Tadeo Lozano', 'Universiti Tun Hussein Onn University of Malaysia (UTHM)', 'Khoja Akhmet Yassawi International Kazakh-Turkish University', 'Northern Borders University', 'Universidad Tecnica Particular De Loja (UPTL)', 'Universidad Central de Chile', 'University of Rzeszów', 'Universidad de Valladolid', 'University of Idaho', 'Universidad del Magdalena', 'University of Toledo', 'Universidad Nacional, Costa Rica', 'Universidad de Santander - UDES', 'Cleveland State University', 'Universidad del Cauca', 'Duy Tan University', 'Universidade Presbiteriana Mackenzie', 'Instituto Tecnológico de Santo Domingo (INTEC)', 'Beijing University of Chemical Technology', 'Ahlia University', 'Universidad de Panama', 'Pontificia Universidade Católica do Minas Gerais - PUC Minas', 'University of North Carolina at Greensboro', 'University of Dubai', 'Nova Southeastern University', 'Universidad Nacional Autónoma de México (UNAM)', 'University of Regina', 'Odessa I.I. Mechnikov National University', 'Universidad de Cuenca', 'International Islamic University Islamabad (IIU)', 'St. Louis University', 'China University of Mining and Technology', 'Toraighyrov University', 'Sciences Po ', 'Universidad Veracruzana', 'Vilnius Gediminas Technical University', 'Universidad Michoacana de San Nicolás de Hidalgo', 'University of Craiova', 'Pontificia Universidad Catolica Madre y Maestra', 'University of South Bohemia', 'Nanjing Agricultural University', 'Universidad Nacional del Comahue', 'Boğaziçi University', "Université Côte d\\'Azur", 'Colegio de México', 'Universidad Nacional de Tucumán', 'National Institute of Technology Tiruchirappalli', 'Sathyabama Institute of Science and Technology (deemed to be university)', 'Future University in Egypt', 'Rutgers, The State University of New Jersey, Camden', 'Erciyes Üniversitesi', 'Pontificia Universidad Católica del Perú', 'Donghua University', 'Universidade do Estado de Santa Catarina', 'Universität Leipzig', 'Indian Institute of Technology Indore (IIT Indore)', "Sungshin Women's University", 'California State University - Los Angeles', 'San Francisco State University', 'Poznan University of Life Sciences', 'Universidad Latinoamericana de Ciencia y Tecnología Costa Rica (ULACIT)', 'Ataturk University', 'Ritsumeikan Asia Pacific ...
